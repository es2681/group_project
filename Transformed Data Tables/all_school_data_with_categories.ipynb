# %%
import pandas as pd

# %%
all_df = pd.read_csv("all_data.csv")
all_df
# Out:
#         DBN                                        School Name All # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY          59
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         132
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL          73
# 3    01M458                          FORSYTH SATELLITE ACADEMY          20
# 4    01M509                            MARTA VALLE HIGH SCHOOL           3
# ..      ...                                                ...         ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE          59
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING          54
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL          63
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...          59
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL          10
#
# ...

# %%
eth_df = pd.read_csv("ethnicities.csv")
eth_df
# Out:
#         DBN                                        School Name Asian # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY             6
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL            38
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL             9
# 3    01M458                          FORSYTH SATELLITE ACADEMY             s
# 4    01M509                            MARTA VALLE HIGH SCHOOL             s
# ..      ...                                                ...           ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE             s
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING           NaN
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL             s
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...           NaN
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL           NaN
#
# ...

# %%
gender_df = pd.read_csv("gender.csv")
gender_df
# Out:
#         DBN                                        School Name Female # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY             33
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL             52
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL             35
# 3    01M458                          FORSYTH SATELLITE ACADEMY             10
# 4    01M509                            MARTA VALLE HIGH SCHOOL              s
# ..      ...                                                ...            ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE             26
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING             25
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL             35
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...             26
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL              8
#
# ...

# %%
poverty_df = pd.read_csv("poverty.csv")
poverty_df
# Out:
#         DBN                                        School Name  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
#
#     Econ Disadv # Grads Econ Disadv % Grads Econ Disadv # Advanced Regents  \
# 0                    47                92.2                              6
# ...

# %%
swd_df = pd.read_csv("swd.csv")
swd_df
# Out:
#         DBN                                        School Name SWD # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY          16
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL          23
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL          13
# 3    01M458                          FORSYTH SATELLITE ACADEMY           7
# 4    01M509                            MARTA VALLE HIGH SCHOOL         NaN
# ..      ...                                                ...         ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE           7
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING          13
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL          12
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...           8
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL           3
#
# ...

# %%
data_frames = [all_df, eth_df, gender_df, poverty_df, swd_df]

# %%
from functools import reduce

# %%
df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DBN'],
                                            how='inner'), data_frames)
df_merged
# Out:
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_28198/4035333205.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'School Name_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['DBN'],
#         DBN                                      School Name_x All # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY          59
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         132
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL          73
# 3    01M458                          FORSYTH SATELLITE ACADEMY          20
# 4    01M509                            MARTA VALLE HIGH SCHOOL           3
# ..      ...                                                ...         ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE          59
# ...

# %%
df_merged.columns
# Out:
# Index(['DBN', 'School Name_x', 'All # Grads', 'All % Grads',
#        'All # Advanced Regents', 'All % Advanced Regents of Cohort',
#        'All # Dropout', 'All % Dropout', 'School Name_y', 'Asian # Grads',
#        'Asian % Grads', 'Asian # Advanced Regents',
#        'Asian % Advanced Regents of Cohort', 'Asian # Dropout',
#        'Asian % Dropout', 'Black # Grads', 'Black % Grads',
#        'Black # Advanced Regents', 'Black % Advanced Regents of Cohort',
#        'Black # Dropout', 'Black % Dropout', 'Hispanic # Grads',
#        'Hispanic % Grads', 'Hispanic # Advanced Regents',
#        'Hispanic % Advanced Regents of Cohort', 'Hispanic # Dropout',
#        'Hispanic % Dropout', 'White # Grads', 'White % Grads',
#        'White # Advanced Regents', 'White % Advanced Regents of Cohort',
#        'White # Dropout', 'White % Dropout', 'Native American # Grads',
#        'Native American % Grads', 'Native American # Advanced Regents',
# ...

# %%
df_merged = df_merged.loc[:,~df_merged.columns.duplicated()]

# %%
df_merged.columns
# Out:
# Index(['DBN', 'School Name_x', 'All # Grads', 'All % Grads',
#        'All # Advanced Regents', 'All % Advanced Regents of Cohort',
#        'All # Dropout', 'All % Dropout', 'School Name_y', 'Asian # Grads',
#        'Asian % Grads', 'Asian # Advanced Regents',
#        'Asian % Advanced Regents of Cohort', 'Asian # Dropout',
#        'Asian % Dropout', 'Black # Grads', 'Black % Grads',
#        'Black # Advanced Regents', 'Black % Advanced Regents of Cohort',
#        'Black # Dropout', 'Black % Dropout', 'Hispanic # Grads',
#        'Hispanic % Grads', 'Hispanic # Advanced Regents',
#        'Hispanic % Advanced Regents of Cohort', 'Hispanic # Dropout',
#        'Hispanic % Dropout', 'White # Grads', 'White % Grads',
#        'White # Advanced Regents', 'White % Advanced Regents of Cohort',
#        'White # Dropout', 'White % Dropout', 'Native American # Grads',
#        'Native American % Grads', 'Native American # Advanced Regents',
# ...

# %%
df_merged = df_merged.drop("School Name_y", 1)
# Out:
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_28198/2387306125.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_merged = df_merged.drop("School Name_y", 1)

# %%
df_merged = df_merged.rename(columns={"School Name_x" : "School Name"})

# %%
df_merged = df_merged.loc[:,~df_merged.columns.duplicated()]

# %%
df_merged
# Out:
#         DBN                                        School Name All # Grads  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY          59
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         132
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL          73
# 3    01M458                          FORSYTH SATELLITE ACADEMY          20
# 4    01M509                            MARTA VALLE HIGH SCHOOL           3
# ..      ...                                                ...         ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE          59
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING          54
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL          63
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...          59
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL          10
#
# ...

# %%
df_merged.dtypes
# Out:
# DBN                                 object
# School Name                         object
# All # Grads                         object
# All % Grads                         object
# All # Advanced Regents              object
#                                      ...
# SWD % Grads                         object
# SWD # Advanced Regents              object
# SWD % Advanced Regents of Cohort    object
# SWD # Dropout                       object
# SWD % Dropout                       object
# Length: 69, dtype: object

# %%
df_unmerged = df_merged.drop(['DBN', 'School Name'], 1)
df_unmerged.dtypes
# Out:
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_28198/4000026493.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df_unmerged = df_merged.drop(['DBN', 'School Name'], 1)
# All # Grads                         object
# All % Grads                         object
# All # Advanced Regents              object
# All % Advanced Regents of Cohort    object
# All # Dropout                       object
#                                      ...
# SWD % Grads                         object
# SWD # Advanced Regents              object
# SWD % Advanced Regents of Cohort    object
# SWD # Dropout                       object
# SWD % Dropout                       object
# Length: 66, dtype: object

# %%
#df_merged = df_merged.fillna(0)

# %%
#df_merged = df_merged.replace(to_replace=\ss\s , value=0 , regex=True)

# %%
#df_merged = df_merged.dropna()

# %%
#value = 's'
#df_merged = df_merged[df_merged.isin(value) == False]

# %%
columns = list(df_unmerged.columns)
for col in columns:
    if "%" in col:
        df_unmerged[col] = df_unmerged[col].astype('float')
        
for col in columns: 
    if "#" in col: 
        df_unmerged[col] = df_unmerged[col].astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_28198/2904659196.py in <module>
#       2 for col in columns:
#       3     if "%" in col:
# ----> 4         df_unmerged = df_unmerged.astype('float')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
df_unmerged.dtypes
# Out:
# All # Grads                         object
# All % Grads                         object
# All # Advanced Regents              object
# All % Advanced Regents of Cohort    object
# All # Dropout                       object
#                                      ...
# SWD % Grads                         object
# SWD # Advanced Regents              object
# SWD % Advanced Regents of Cohort    object
# SWD # Dropout                       object
# SWD % Dropout                       object
# Length: 66, dtype: object

# %%
#df_merged = df_unmerged.appendleft(df_merged['DBN', 'School Name'])

# %%
#df_merged.dtypes

# %%
#df_merged.to_csv("all_school_data_with_categories.csv", index=False)
