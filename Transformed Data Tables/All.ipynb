# %%
import pandas as pd

# %%
df = pd.read_csv("../source/All.csv")
df
# Out:
#           DBN                     School Name      Category  Cohort Year  \
# 0      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2017
# 1      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2016
# 2      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2015
# 3      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2014
# 4      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2013
# ...       ...                             ...           ...          ...
# 31187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2005
# 31188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2004
# 31189  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2003
# 31190  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2002
# 31191  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2001
#
#               Cohort  # Total Cohort # Grads % Grads # Total Regents  \
# 0      4 year August              65      61    93.8              61
# 1      4 year August              31      29    93.5              29
# 2      4 year August              28      25    89.3              22
# 3      4 year August              29      28    96.6              25
# 4      4 year August              36      25    69.4              23
# ...              ...             ...     ...     ...             ...
# 31187    6 year June             208      61    29.3              24
# 31188    6 year June             189      48    25.4              14
# 31189    6 year June             144      42    29.2               5
# 31190    6 year June             179      60    33.5               1
# 31191    6 year June             159      63    39.6               0
#
#       % Total Regents of Cohort  ... # Regents without Advanced  \
# 0                          93.8  ...                         53
# 1                          93.5  ...                         20
# 2                          78.6  ...                         20
# 3                          86.2  ...                         25
# 4                          63.9  ...                         23
# ...                         ...  ...                        ...
# 31187                      11.5  ...                         24
# 31188                       7.4  ...                         14
# 31189                       3.5  ...                          5
# 31190                       0.6  ...                          1
# 31191                       0.0  ...                          0
#
#       % Regents without Advanced of Cohort  \
# 0                                     81.5
# 1                                     64.5
# 2                                     71.4
# 3                                     86.2
# 4                                     63.9
# ...                                    ...
# 31187                                 11.5
# 31188                                  7.4
# 31189                                  3.5
# 31190                                  0.6
# 31191                                  0.0
#
#       % Regents without Advanced of Grads # Local % Local of Cohort  \
# 0                                    86.9       0               0.0
# 1                                    69.0       0               0.0
# 2                                    80.0       3              10.7
# 3                                    89.3       3              10.3
# 4                                    92.0       2               5.6
# ...                                   ...     ...               ...
# 31187                                39.3      37              17.8
# 31188                                29.2      34              18.0
# 31189                                11.9      37              25.7
# 31190                                 1.7      59              33.0
# 31191                                 0.0      63              39.6
#
#       % Local of Grads # Still Enrolled % Still Enrolled # Dropout % Dropout
# 0                  0.0                4              6.2         0       0.0
# 1                  0.0                1              3.2         1       3.2
# 2                 12.0                0              0.0         3      10.7
# 3                 10.7                0              0.0         1       3.4
# 4                  8.0                3              8.3         7      19.4
# ...                ...              ...              ...       ...       ...
# 31187             60.7               26             12.5       117      56.3
# 31188             70.8               29             15.3       105      55.6
# 31189             88.1               17             11.8        84      58.3
# 31190             98.3               25             14.0        93      52.0
# 31191            100.0               20             12.6        74      46.5
#
# [31192 rows x 24 columns]

# %%
column_list = ['DBN', 'School Name', 'Cohort Year', 'Cohort', 'Category', '# Grads', '% Grads', '# Advanced Regents', '% Advanced Regents of Cohort', '# Dropout', '% Dropout']
column_list
# Out:
# ['DBN',
#  'School Name',
#  'Cohort Year',
#  'Cohort',
#  'Category',
#  '# Grads',
#  '% Grads',
#  '# Advanced Regents',
#  '% Advanced Regents of Cohort',
#  '# Dropout',
#  '% Dropout']

# %%
df1 = df[column_list].copy()
df1
# Out:
#           DBN                     School Name  Cohort Year         Cohort  \
# 0      01M292      ORCHARD COLLEGIATE ACADEMY         2017  4 year August
# 1      01M292      ORCHARD COLLEGIATE ACADEMY         2016  4 year August
# 2      01M292      ORCHARD COLLEGIATE ACADEMY         2015  4 year August
# 3      01M292      ORCHARD COLLEGIATE ACADEMY         2014  4 year August
# 4      01M292      ORCHARD COLLEGIATE ACADEMY         2013  4 year August
# ...       ...                             ...          ...            ...
# 31187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005    6 year June
# 31188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004    6 year June
# 31189  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003    6 year June
# 31190  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002    6 year June
# 31191  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001    6 year June
#
#            Category # Grads % Grads # Advanced Regents  \
# 0      All Students      61    93.8                  8
# 1      All Students      29    93.5                  9
# 2      All Students      25    89.3                  2
# 3      All Students      28    96.6                  0
# 4      All Students      25    69.4                  0
# ...             ...     ...     ...                ...
# 31187  All Students      61    29.3                  0
# 31188  All Students      48    25.4                  0
# 31189  All Students      42    29.2                  0
# 31190  All Students      60    33.5                  0
# 31191  All Students      63    39.6                  0
#
#       % Advanced Regents of Cohort # Dropout % Dropout
# 0                             12.3         0       0.0
# 1                             29.0         1       3.2
# 2                              7.1         3      10.7
# 3                              0.0         1       3.4
# 4                              0.0         7      19.4
# ...                            ...       ...       ...
# 31187                          0.0       117      56.3
# 31188                          0.0       105      55.6
# 31189                          0.0        84      58.3
# 31190                          0.0        93      52.0
# 31191                          0.0        74      46.5
#
# [31192 rows x 11 columns]

# %%
df2 = df1.loc[(df1['Cohort'] == '4 year June') & (df1['Cohort Year'] == 2017)]
df2
# Out:
#           DBN                                        School Name  Cohort Year  \
# 13     01M292                         ORCHARD COLLEGIATE ACADEMY         2017
# 79     01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         2017
# 151    01M450                         EAST SIDE COMMUNITY SCHOOL         2017
# 221    01M458                          FORSYTH SATELLITE ACADEMY         2017
# 278    01M509                            MARTA VALLE HIGH SCHOOL         2017
# ...       ...                                                ...          ...
# 30854  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE         2017
# 30923  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING         2017
# 30995  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL         2017
# 31064  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...         2017
# 31133  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL         2017
#
#             Cohort      Category # Grads % Grads # Advanced Regents  \
# 13     4 year June  All Students      59    90.8                  8
# 79     4 year June  All Students     132    98.5                 71
# 151    4 year June  All Students      73    92.4                  0
# 221    4 year June  All Students      20    36.4                  0
# 278    4 year June  All Students       3    50.0                  0
# ...            ...           ...     ...     ...                ...
# 30854  4 year June  All Students      59    75.6                 12
# 30923  4 year June  All Students      54    98.2                  3
# 30995  4 year June  All Students      63    98.4                 47
# 31064  4 year June  All Students      59    84.3                 34
# 31133  4 year June  All Students      10    18.9                  0
#
#       % Advanced Regents of Cohort # Dropout % Dropout
# 13                            12.3         0       0.0
# 79                            53.0         2       1.5
# 151                            0.0         0       0.0
# 221                            0.0         2       3.6
# 278                            0.0         3      50.0
# ...                            ...       ...       ...
# 30854                         15.4         3       3.8
# 30923                          5.5         0       0.0
# 30995                         73.4         0       0.0
# 31064                         48.6         2       2.9
# 31133                          0.0         8      15.1
#
# [471 rows x 11 columns]

# %%
df2['Category'].value_counts()
school_names = df2[['DBN', 'School Name']].drop_duplicates()
school_names
# Out:
#           DBN                                        School Name
# 13     01M292                         ORCHARD COLLEGIATE ACADEMY
# 79     01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 151    01M450                         EAST SIDE COMMUNITY SCHOOL
# 221    01M458                          FORSYTH SATELLITE ACADEMY
# 278    01M509                            MARTA VALLE HIGH SCHOOL
# ...       ...                                                ...
# 30854  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE
# 30923  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING
# 30995  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 31064  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 31133  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
#
# [471 rows x 2 columns]

# %%
all = school_names.merge(df2, how = 'left', on = 'DBN')
all
# Out:
#         DBN                                      School Name_x  \
# 0    01M292                         ORCHARD COLLEGIATE ACADEMY
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 466  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE
# 467  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING
# 468  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 469  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 470  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
#
#                                          School Name_y  Cohort Year  \
# 0                           ORCHARD COLLEGIATE ACADEMY         2017
# 1                  UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         2017
# 2                           EAST SIDE COMMUNITY SCHOOL         2017
# 3                            FORSYTH SATELLITE ACADEMY         2017
# 4                              MARTA VALLE HIGH SCHOOL         2017
# ..                                                 ...          ...
# 466             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE         2017
# 467      THE ACADEMY OF URBAN PLANNING AND ENGINEERING         2017
# 468               ALL CITY LEADERSHIP SECONDARY SCHOOL         2017
# 469  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...         2017
# 470                     BUSHWICK COMMUNITY HIGH SCHOOL         2017
#
#           Cohort      Category # Grads % Grads # Advanced Regents  \
# 0    4 year June  All Students      59    90.8                  8
# 1    4 year June  All Students     132    98.5                 71
# 2    4 year June  All Students      73    92.4                  0
# 3    4 year June  All Students      20    36.4                  0
# 4    4 year June  All Students       3    50.0                  0
# ..           ...           ...     ...     ...                ...
# 466  4 year June  All Students      59    75.6                 12
# 467  4 year June  All Students      54    98.2                  3
# 468  4 year June  All Students      63    98.4                 47
# 469  4 year June  All Students      59    84.3                 34
# 470  4 year June  All Students      10    18.9                  0
#
#     % Advanced Regents of Cohort # Dropout % Dropout
# 0                           12.3         0       0.0
# 1                           53.0         2       1.5
# 2                            0.0         0       0.0
# 3                            0.0         2       3.6
# 4                            0.0         3      50.0
# ..                           ...       ...       ...
# 466                         15.4         3       3.8
# 467                          5.5         0       0.0
# 468                         73.4         0       0.0
# 469                         48.6         2       2.9
# 470                          0.0         8      15.1
#
# [471 rows x 12 columns]
