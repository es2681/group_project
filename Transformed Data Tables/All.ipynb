# %%
import pandas as pd

# %%
df = pd.read_csv("../source/All.csv")
df
# Out:
#           DBN                     School Name      Category  Cohort Year  \
# 0      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2017
# 1      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2016
# 2      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2015
# 3      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2014
# 4      01M292      ORCHARD COLLEGIATE ACADEMY  All Students         2013
# ...       ...                             ...           ...          ...
# 31187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2005
# 31188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2004
# 31189  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2003
# 31190  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2002
# 31191  32K564  BUSHWICK COMMUNITY HIGH SCHOOL  All Students         2001
#
#               Cohort  # Total Cohort # Grads % Grads # Total Regents  \
# ...

# %%
column_list = ['DBN', 'School Name', 'Cohort Year', 'Cohort', '# Total Cohort', '# Grads', '% Grads', '# Total Regents', '% Total Regents of Cohort', '# Advanced Regents', '% Advanced Regents of Cohort', '# Dropout', '% Dropout']
column_list
# Out:
# ['DBN',
#  'School Name',
#  'Cohort Year',
#  'Cohort',
#  '# Total Cohort',
#  '# Grads',
#  '% Grads',
#  '# Total Regents',
#  '% Total Regents of Cohort',
#  '# Advanced Regents',
#  '% Advanced Regents of Cohort',
#  '# Dropout',
#  '% Dropout']

# %%
df1 = df[column_list].copy()
df1
# Out:
#           DBN                     School Name  Cohort Year         Cohort  \
# 0      01M292      ORCHARD COLLEGIATE ACADEMY         2017  4 year August
# 1      01M292      ORCHARD COLLEGIATE ACADEMY         2016  4 year August
# 2      01M292      ORCHARD COLLEGIATE ACADEMY         2015  4 year August
# 3      01M292      ORCHARD COLLEGIATE ACADEMY         2014  4 year August
# 4      01M292      ORCHARD COLLEGIATE ACADEMY         2013  4 year August
# ...       ...                             ...          ...            ...
# 31187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005    6 year June
# 31188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004    6 year June
# 31189  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003    6 year June
# 31190  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002    6 year June
# 31191  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001    6 year June
#
#        # Total Cohort # Grads % Grads # Total Regents  \
# ...

# %%
df2 = df1.loc[df1['Cohort'] == '4 year June']
df2
# Out:
#           DBN                     School Name  Cohort Year       Cohort  \
# 13     01M292      ORCHARD COLLEGIATE ACADEMY         2017  4 year June
# 14     01M292      ORCHARD COLLEGIATE ACADEMY         2016  4 year June
# 15     01M292      ORCHARD COLLEGIATE ACADEMY         2015  4 year June
# 16     01M292      ORCHARD COLLEGIATE ACADEMY         2014  4 year June
# 17     01M292      ORCHARD COLLEGIATE ACADEMY         2013  4 year June
# ...       ...                             ...          ...          ...
# 31145  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005  4 year June
# 31146  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004  4 year June
# 31147  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003  4 year June
# 31148  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002  4 year June
# 31149  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001  4 year June
#
#        # Total Cohort # Grads % Grads # Total Regents  \
# ...

# %%
school_names = df2[['DBN', 'School Name']].drop_duplicates()
school_names
# Out:
#           DBN                                        School Name
# 13     01M292                         ORCHARD COLLEGIATE ACADEMY
# 79     01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 151    01M450                         EAST SIDE COMMUNITY SCHOOL
# 221    01M458                          FORSYTH SATELLITE ACADEMY
# 278    01M509                            MARTA VALLE HIGH SCHOOL
# ...       ...                                                ...
# 30854  32K549             THE BROOKLYN SCHOOL FOR SOCIAL JUSTICE
# 30923  32K552      THE ACADEMY OF URBAN PLANNING AND ENGINEERING
# 30995  32K554               ALL CITY LEADERSHIP SECONDARY SCHOOL
# 31064  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 31133  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
#
# [556 rows x 2 columns]

# %%
all_df = df2[['DBN', 'Cohort Year', '# Total Cohort', '# Grads', '% Grads', '# Total Regents', '% Total Regents of Cohort', '# Advanced Regents', '% Advanced Regents of Cohort', '# Dropout', '% Dropout']]#.set_index('DBN')
#all_df  = all_df.add_prefix('All ').reset_index()
all_df
# Out:
#           DBN  Cohort Year  # Total Cohort # Grads % Grads # Total Regents  \
# 13     01M292         2017              65      59    90.8              59
# 14     01M292         2016              31      29    93.5              29
# 15     01M292         2015              28      25    89.3              22
# 16     01M292         2014              29      25    86.2              22
# 17     01M292         2013              36      24    66.7              23
# ...       ...          ...             ...     ...     ...             ...
# 31145  32K564         2005             140       5     3.6               3
# 31146  32K564         2004             113       7     6.2               0
# 31147  32K564         2003             129       4     3.1               0
# 31148  32K564         2002             179       7     3.9               0
# 31149  32K564         2001             159      10     6.3               0
#
#       % Total Regents of Cohort # Advanced Regents  \
# ...

# %%
#all_df = all_df.rename({'All Cohort Year': 'Cohort Year', 'All # Total Cohort': '# Total Cohort'}, axis=1)
#all_df
# Out:
#           DBN  Cohort Year  # Total Cohort # Grads % Grads # Total Regents  \
# 13     01M292         2017              65      59    90.8              59
# 14     01M292         2016              31      29    93.5              29
# 15     01M292         2015              28      25    89.3              22
# 16     01M292         2014              29      25    86.2              22
# 17     01M292         2013              36      24    66.7              23
# ...       ...          ...             ...     ...     ...             ...
# 31145  32K564         2005             140       5     3.6               3
# 31146  32K564         2004             113       7     6.2               0
# 31147  32K564         2003             129       4     3.1               0
# 31148  32K564         2002             179       7     3.9               0
# 31149  32K564         2001             159      10     6.3               0
#
#       % Total Regents of Cohort # Advanced Regents  \
# ...

# %%
all = school_names.merge(all_df, how = 'left', on = 'DBN')
all
# Out:
#          DBN                     School Name  Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013              36
# ...      ...                             ...          ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005             140
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004             113
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003             129
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002             179
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001             159
#
#      # Grads % Grads # Total Regents % Total Regents of Cohort  \
# ...

# %%
all.to_csv("transformed_all_table.csv", index=False)
