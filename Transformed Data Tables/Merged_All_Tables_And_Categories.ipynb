# %%
import pandas as pd

# %%
all_df = pd.read_csv("transformed_all_table.csv")
all_df
# Out:
#          DBN                     School Name  Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013              36
# ...      ...                             ...          ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005             140
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004             113
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003             129
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002             179
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001             159
#
#      # Grads % Grads # Total Regents % Total Regents of Cohort  \
# ...

# %%
all_short_df = all_df.drop(['# Grads', '# Total Regents', '# Advanced Regents', '# Dropout'], 1)
all_short_df
# Out:
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_38003/391610778.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   all_short_df = all_df.drop(['# Grads', '# Total Regents', '# Advanced Regents', '# Dropout'], 1)
#          DBN                     School Name  Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013              36
# ...      ...                             ...          ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005             140
# ...

# %%
eth_df = pd.read_csv("transformed_ethnicities_table.csv")
eth_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2010
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2009
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2008
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Asian # Total Cohort Asian # Grads Asian % Grads Asian # Total Regents  \
# 0                      6.0             6           100                     6
# 1                      7.0             6          85.7                     6
# ...

# %%
eth_df.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', 'Asian # Total Cohort',
#        'Asian # Grads', 'Asian % Grads', 'Asian # Total Regents',
#        'Asian % Total Regents of Cohort', 'Asian # Advanced Regents',
#        'Asian % Advanced Regents of Cohort', 'Asian # Dropout',
#        'Asian % Dropout', 'Black # Total Cohort', 'Black # Grads',
#        'Black % Grads', 'Black # Total Regents',
#        'Black % Total Regents of Cohort', 'Black # Advanced Regents',
#        'Black % Advanced Regents of Cohort', 'Black # Dropout',
#        'Black % Dropout', 'Hispanic # Total Cohort', 'Hispanic # Grads',
#        'Hispanic % Grads', 'Hispanic # Total Regents',
#        'Hispanic % Total Regents of Cohort', 'Hispanic # Advanced Regents',
#        'Hispanic % Advanced Regents of Cohort', 'Hispanic # Dropout',
#        'Hispanic % Dropout', 'White # Total Cohort', 'White # Grads',
#        'White % Grads', 'White # Total Regents',
# ...

# %%
eth_short_df = eth_df[['DBN', 'School Name', 'Cohort Year', 'Asian # Total Cohort', 'Black # Total Cohort', 'Hispanic # Total Cohort', 'White # Total Cohort', 'Native American # Total Cohort', 'Multi-Racial # Total Cohort']]
eth_short_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2010
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2009
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2008
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Asian # Total Cohort  Black # Total Cohort  Hispanic # Total Cohort  \
# 0                      6.0                  17.0                     39.0
# 1                      7.0                  11.0                      9.0
# ...

# %%
gender_df = pd.read_csv("transformed_gender_table.csv")
gender_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Female # Total Cohort Female # Grads Female % Grads  \
# 0                      35.0             33           94.3
# 1                      16.0             15           93.8
# 2                      10.0              7           70.0
# ...

# %%
gender_df.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', 'Female # Total Cohort',
#        'Female # Grads', 'Female % Grads', 'Female # Total Regents',
#        'Female % Total Regents of Cohort', 'Female # Advanced Regents',
#        'Female % Advanced Regents of Cohort', 'Female # Dropout',
#        'Female % Dropout', 'Male # Total Cohort', 'Male # Grads',
#        'Male % Grads', 'Male # Total Regents',
#        'Male % Total Regents of Cohort', 'Male # Advanced Regents',
#        'Male % Advanced Regents of Cohort', 'Male # Dropout',
#        'Male % Dropout'],
#       dtype='object')

# %%
gender_short_df = gender_df[['DBN', 'School Name', 'Cohort Year', 'Female # Total Cohort', 'Male # Total Cohort']]
gender_short_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Female # Total Cohort  Male # Total Cohort
# 0                      35.0                 30.0
# 1                      16.0                 15.0
# 2                      10.0                 18.0
# 3                       6.0                 23.0
# ...

# %%
poverty_df = pd.read_csv("transformed_poverty_table.csv")
poverty_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Econ Disadv # Total Cohort Econ Disadv # Grads Econ Disadv % Grads  \
# 0                           51.0                  47                92.2
# 1                           26.0                   s                   s
# ...

# %%
poverty_df.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', 'Econ Disadv # Total Cohort',
#        'Econ Disadv # Grads', 'Econ Disadv % Grads',
#        'Econ Disadv # Total Regents', 'Econ Disadv % Total Regents of Cohort',
#        'Econ Disadv # Advanced Regents',
#        'Econ Disadv % Advanced Regents of Cohort', 'Econ Disadv # Dropout',
#        'Econ Disadv % Dropout', 'Not Econ Disadv # Total Cohort',
#        'Not Econ Disadv # Grads', 'Not Econ Disadv % Grads',
#        'Not Econ Disadv # Total Regents',
#        'Not Econ Disadv % Total Regents of Cohort',
#        'Not Econ Disadv # Advanced Regents',
#        'Not Econ Disadv % Advanced Regents of Cohort',
#        'Not Econ Disadv # Dropout', 'Not Econ Disadv % Dropout'],
#       dtype='object')

# %%
poverty_short_df = poverty_df[['DBN', 'School Name', 'Cohort Year', 'Econ Disadv # Total Cohort', 'Not Econ Disadv # Total Cohort']]
poverty_short_df
# Out:
#          DBN                     School Name  Cohort Year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       Econ Disadv # Total Cohort  Not Econ Disadv # Total Cohort
# 0                           51.0                            14.0
# 1                           26.0                             5.0
# 2                           23.0                             5.0
# ...

# %%
swd_df = pd.read_csv("transformed_swd_table.csv")
swd_df
# Out:
#          DBN                     School Name  Cohort Year  SWD # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017                20.0
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016                 7.0
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015                 8.0
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014                 8.0
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013                12.0
# ...      ...                             ...          ...                 ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005                21.0
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004                14.0
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003                15.0
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002                17.0
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001                11.0
#
# ...

# %%
swd_df.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', 'SWD # Total Cohort',
#        'SWD # Grads', 'SWD % Grads', 'SWD # Total Regents',
#        'SWD % Total Regents of Cohort', 'SWD # Advanced Regents',
#        'SWD % Advanced Regents of Cohort', 'SWD # Dropout', 'SWD % Dropout',
#        'Not SWD # Total Cohort', 'Not SWD # Grads', 'Not SWD % Grads',
#        'Not SWD # Total Regents', 'Not SWD % Total Regents of Cohort',
#        'Not SWD # Advanced Regents', 'Not SWD % Advanced Regents of Cohort',
#        'Not SWD # Dropout', 'Not SWD % Dropout'],
#       dtype='object')

# %%
swd_short_df = swd_df[['DBN', 'School Name', 'Cohort Year', 'SWD # Total Cohort', 'Not SWD # Total Cohort']]
swd_short_df
# Out:
#          DBN                     School Name  Cohort Year  SWD # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017                20.0
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016                 7.0
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015                 8.0
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014                 8.0
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013                12.0
# ...      ...                             ...          ...                 ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005                21.0
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004                14.0
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003                15.0
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002                17.0
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001                11.0
#
#       Not SWD # Total Cohort
# ...

# %%
df_merged = pd.concat([all_short_df, eth_short_df, gender_short_df, poverty_short_df, swd_short_df], join='inner', axis=1)
df_merged
# Out:
#          DBN                     School Name Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY        2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY        2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY        2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY        2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY        2013              36
# ...      ...                             ...         ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL        2005             140
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL        2004             113
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL        2003             129
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL        2002             179
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL        2001             159
#
#      % Grads % Total Regents of Cohort % Advanced Regents of Cohort % Dropout  \
# ...

# %%
df_merged.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', '# Total Cohort', '% Grads',
#        '% Total Regents of Cohort', '% Advanced Regents of Cohort',
#        '% Dropout', 'DBN', 'School Name', 'Cohort Year',
#        'Asian # Total Cohort', 'Black # Total Cohort',
#        'Hispanic # Total Cohort', 'White # Total Cohort',
#        'Native American # Total Cohort', 'Multi-Racial # Total Cohort', 'DBN',
#        'School Name', 'Cohort Year', 'Female # Total Cohort',
#        'Male # Total Cohort', 'DBN', 'School Name', 'Cohort Year',
#        'Econ Disadv # Total Cohort', 'Not Econ Disadv # Total Cohort', 'DBN',
#        'School Name', 'Cohort Year', 'SWD # Total Cohort',
#        'Not SWD # Total Cohort'],
#       dtype='object')

# %%
df_merged = df_merged.loc[:,~df_merged.columns.duplicated()]

# %%
df_merged.columns
# Out:
# Index(['DBN', 'School Name', 'Cohort Year', '# Total Cohort', '% Grads',
#        '% Total Regents of Cohort', '% Advanced Regents of Cohort',
#        '% Dropout', 'Asian # Total Cohort', 'Black # Total Cohort',
#        'Hispanic # Total Cohort', 'White # Total Cohort',
#        'Native American # Total Cohort', 'Multi-Racial # Total Cohort',
#        'Female # Total Cohort', 'Male # Total Cohort',
#        'Econ Disadv # Total Cohort', 'Not Econ Disadv # Total Cohort',
#        'SWD # Total Cohort', 'Not SWD # Total Cohort'],
#       dtype='object')

# %%
s_list = df_merged[df_merged['% Grads']=='s'].index.tolist()

# %%
clean_df_merged = df_merged.drop(s_list, axis=0)
clean_df_merged
# Out:
#          DBN                     School Name  Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013              36
# ...      ...                             ...          ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005             140
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004             113
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003             129
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002             179
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001             159
#
#      % Grads % Total Regents of Cohort % Advanced Regents of Cohort % Dropout  \
# ...

# %%
clean_df_merged.shape
# Out:
# (6832, 20)

# %%
clean_df_merged.isnull().sum()
# Out:
# DBN                                  0
# School Name                          0
# Cohort Year                          0
# # Total Cohort                       0
# % Grads                              0
# % Total Regents of Cohort            0
# % Advanced Regents of Cohort         0
# % Dropout                            0
# Asian # Total Cohort              1296
# Black # Total Cohort               102
# Hispanic # Total Cohort             39
# White # Total Cohort              1381
# Native American # Total Cohort    3841
# Multi-Racial # Total Cohort       4752
# Female # Total Cohort               68
# Male # Total Cohort                 91
# Econ Disadv # Total Cohort          14
# Not Econ Disadv # Total Cohort     259
# SWD # Total Cohort                 222
# Not SWD # Total Cohort              20
# dtype: int64

# %%
clean_df_merged = clean_df_merged.fillna(0)

# %%
clean_df_merged.isnull().sum()
# Out:
# DBN                               0
# School Name                       0
# Cohort Year                       0
# # Total Cohort                    0
# % Grads                           0
# % Total Regents of Cohort         0
# % Advanced Regents of Cohort      0
# % Dropout                         0
# Asian # Total Cohort              0
# Black # Total Cohort              0
# Hispanic # Total Cohort           0
# White # Total Cohort              0
# Native American # Total Cohort    0
# Multi-Racial # Total Cohort       0
# Female # Total Cohort             0
# Male # Total Cohort               0
# Econ Disadv # Total Cohort        0
# Not Econ Disadv # Total Cohort    0
# SWD # Total Cohort                0
# Not SWD # Total Cohort            0
# dtype: int64

# %%
clean_df_merged.dtypes
# Out:
# DBN                                object
# School Name                        object
# Cohort Year                         int64
# # Total Cohort                      int64
# % Grads                            object
# % Total Regents of Cohort          object
# % Advanced Regents of Cohort       object
# % Dropout                          object
# Asian # Total Cohort              float64
# Black # Total Cohort              float64
# Hispanic # Total Cohort           float64
# White # Total Cohort              float64
# Native American # Total Cohort    float64
# Multi-Racial # Total Cohort       float64
# Female # Total Cohort             float64
# Male # Total Cohort               float64
# Econ Disadv # Total Cohort        float64
# Not Econ Disadv # Total Cohort    float64
# SWD # Total Cohort                float64
# Not SWD # Total Cohort            float64
# dtype: object

# %%
columns = list(clean_df_merged.columns)
for col in columns:
    if "%" in col:
        clean_df_merged[col] = clean_df_merged[col].astype('float')
        
for col in columns: 
    if "#" in col: 
        clean_df_merged[col] = clean_df_merged[col].astype('int64')

# %%
clean_df_merged.dtypes
# Out:
# DBN                                object
# School Name                        object
# Cohort Year                         int64
# # Total Cohort                      int64
# % Grads                           float64
# % Total Regents of Cohort         float64
# % Advanced Regents of Cohort      float64
# % Dropout                         float64
# Asian # Total Cohort                int64
# Black # Total Cohort                int64
# Hispanic # Total Cohort             int64
# White # Total Cohort                int64
# Native American # Total Cohort      int64
# Multi-Racial # Total Cohort         int64
# Female # Total Cohort               int64
# Male # Total Cohort                 int64
# Econ Disadv # Total Cohort          int64
# Not Econ Disadv # Total Cohort      int64
# SWD # Total Cohort                  int64
# Not SWD # Total Cohort              int64
# dtype: object

# %%
clean_df_merged['% Asian Cohort'] = (clean_df_merged['Asian # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Black Cohort'] = (clean_df_merged['Black # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Hispanic Cohort'] = (clean_df_merged['Hispanic # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% White Cohort'] = (clean_df_merged['White # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Native American Cohort'] = (clean_df_merged['Native American # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Multi-Racial Cohort'] = (clean_df_merged['Multi-Racial # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Female Cohort'] = (clean_df_merged['Female # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Male Cohort'] = (clean_df_merged['Male # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Econ Disadv Cohort'] = (clean_df_merged['Econ Disadv # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Not Econ Disadv Cohort'] = (clean_df_merged['Not Econ Disadv # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% SWD Cohort'] = (clean_df_merged['SWD # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged['% Not SWD Cohort'] = (clean_df_merged['Not SWD # Total Cohort'] / clean_df_merged['# Total Cohort']) * 100
clean_df_merged
# Out:
#          DBN                     School Name  Cohort Year  # Total Cohort  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017              65
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016              31
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015              28
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014              29
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013              36
# ...      ...                             ...          ...             ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005             140
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004             113
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003             129
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002             179
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001             159
#
#       % Grads  % Total Regents of Cohort  % Advanced Regents of Cohort  \
# ...

# %%
clean_df_merged = clean_df_merged.drop(['# Total Cohort', 'Asian # Total Cohort', 'Black # Total Cohort',
       'Hispanic # Total Cohort', 'White # Total Cohort',
       'Native American # Total Cohort', 'Multi-Racial # Total Cohort',
       'Female # Total Cohort', 'Male # Total Cohort',
       'Econ Disadv # Total Cohort', 'Not Econ Disadv # Total Cohort',
       'SWD # Total Cohort', 'Not SWD # Total Cohort',], 1)
# Out:
# /var/folders/zv/yt8ht1rx5b53km5qqd7ntj_80000gn/T/ipykernel_38003/1459783425.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   clean_df_merged = clean_df_merged.drop(['# Total Cohort', 'Asian # Total Cohort', 'Black # Total Cohort',

# %%
columns = list(clean_df_merged.columns)
for col in columns: 
    if clean_df_merged[col].dtypes == 'float64':
        clean_df_merged.round(1)
        
clean_df_merged
# Out:
#          DBN                     School Name  Cohort Year  % Grads  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017     90.8
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016     93.5
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015     89.3
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014     86.2
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013     66.7
# ...      ...                             ...          ...      ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005      3.6
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004      6.2
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003      3.1
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002      3.9
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001      6.3
#
#       % Total Regents of Cohort  % Advanced Regents of Cohort  % Dropout  \
# 0                          90.8                          12.3        0.0
# ...

# %%
clean_df_merged = clean_df_merged.round(1)
clean_df_merged
# Out:
#          DBN                     School Name  Cohort Year  % Grads  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017     90.8
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016     93.5
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015     89.3
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014     86.2
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013     66.7
# ...      ...                             ...          ...      ...
# 7184  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005      3.6
# 7185  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004      6.2
# 7186  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003      3.1
# 7187  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002      3.9
# 7188  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001      6.3
#
#       % Total Regents of Cohort  % Advanced Regents of Cohort  % Dropout  \
# 0                          90.8                          12.3        0.0
# ...

# %%
clean_df_merged['School Name and Cohort Year'] = clean_df_merged['School Name'] + clean_df_merged['Cohort Year'].astype(str)
clean_df_merged.head()
# Out:
#       DBN                 School Name  Cohort Year  % Grads  \
# 0  01M292  ORCHARD COLLEGIATE ACADEMY         2017     90.8
# 1  01M292  ORCHARD COLLEGIATE ACADEMY         2016     93.5
# 2  01M292  ORCHARD COLLEGIATE ACADEMY         2015     89.3
# 3  01M292  ORCHARD COLLEGIATE ACADEMY         2014     86.2
# 4  01M292  ORCHARD COLLEGIATE ACADEMY         2013     66.7
#
#    % Total Regents of Cohort  % Advanced Regents of Cohort  % Dropout  \
# 0                       90.8                          12.3        0.0
# 1                       93.5                          29.0        3.2
# 2                       78.6                           7.1       10.7
# 3                       75.9                           0.0        3.4
# 4                       63.9                           0.0       19.4
#
#    % Asian Cohort  % Black Cohort  % Hispanic Cohort  % White Cohort  \
# 0             9.2            26.2               60.0             1.5
# ...

# %%
clean_df_merged.columns = clean_df_merged.columns.str.replace('%', 'Percent')
clean_df_merged.columns = clean_df_merged.columns.map(lambda x : x.replace("_", "-").replace("-", ""))
clean_df_merged.columns
# Out:
# Index(['DBN', 'SchoolName', 'CohortYear', 'PercentGrads',
#        'PercentTotalRegentsofCohort', 'PercentAdvancedRegentsofCohort',
#        'PercentDropout', 'PercentAsianCohort', 'PercentBlackCohort',
#        'PercentHispanicCohort', 'PercentWhiteCohort',
#        'PercentNativeAmericanCohort', 'PercentMultiRacialCohort',
#        'PercentFemaleCohort', 'PercentMaleCohort', 'PercentEconDisadvCohort',
#        'PercentNotEconDisadvCohort', 'PercentSWDCohort', 'PercentNotSWDCohort',
#        'SchoolNameandCohortYear'],
#       dtype='object')

# %%
clean_df_merged.to_csv("all_data_concat.csv", index=False)

# %%
clean_df_merged.to_csv("all_school_data_with_categories.csv", index=False)
