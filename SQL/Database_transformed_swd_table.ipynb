# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/student_analysis_project/SQL/swd_all.csv"
swd_all_df = pd.read_csv(file_path)
swd_all_df
# Out:
#             dbn                     school_name  cohort_year  \
# 0        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 2        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 3        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 4        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# ...         ...                             ...          ...
# 1376897  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
# 1376898  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
# 1376899  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
# 1376900  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
# 1376901  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#          swd_num_total_cohort  swd_num_grads  swd_percent_grads  \
# 0                           2              0                0.0
# 1                           2              0                0.0
# ...

# %%
swd_all_df.drop_duplicates(subset=['dbn','school_name','cohort_year'])
# Out:
#             dbn                     school_name  cohort_year  \
# 0        01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 225      01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 450      01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 675      01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 900      01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...         ...                             ...          ...
# 1375542  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 1375814  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 1376086  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 1376358  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 1376630  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#          swd_num_total_cohort  swd_num_grads  swd_percent_grads  \
# 0                           2              0                0.0
# 225                         2              0                0.0
# ...

# %%
swd_all_df.to_csv("/Users/pace/Desktop/Columbia Bootcamp/Final Project/student_analysis_project/SQL/transformed_swd_all", index=False)
