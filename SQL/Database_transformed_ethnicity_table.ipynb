# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/ethnicity_asian.csv"
asian_all_df = pd.read_csv(file_path)
asian_all_df
# Out:
#          dbn                     school_name  cohort_year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 5603  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2007
# 5604  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2006
# 5605  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 5606  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 5607  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
#
#       asian_num_total_cohort  asian_num_grads  asian_percent_grads  \
# 0                          6                6                100.0
# 1                          7                6                 85.7
# ...

# %%
column_list = ['DBN', 'School Name', 'Cohort Year', 'Cohort', 'Category', '# Total Cohort', '# Grads', '% Grads', '# Total Regents', '% Total Regents of Cohort', '# Advanced Regents', '% Advanced Regents of Cohort', '# Dropout', '% Dropout']
column_list
# Out:
# ['DBN',
#  'School Name',
#  'Cohort Year',
#  'Cohort',
#  'Category',
#  '# Total Cohort',
#  '# Grads',
#  '% Grads',
#  '# Total Regents',
#  '% Total Regents of Cohort',
#  '# Advanced Regents',
#  '% Advanced Regents of Cohort',
#  '# Dropout',
#  '% Dropout']

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/ethnicity_hispanic.csv"
hispanic_all_df = pd.read_csv(file_path)
hispanic_all_df
# Out:
#          dbn                     school_name  cohort_year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 7025  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 7026  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 7027  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 7028  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 7029  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       hispanic_num_total_cohort  hispanic_num_grads  hispanic_percent_grads  \
# 0                            39                  34                    87.2
# 1                             9                   9                   100.0
# ...

# %%
column_list = ['DBN', 'School Name', 'Cohort Year', 'Cohort', 'Category', '# Total Cohort', '# Grads', '% Grads', '# Total Regents', '% Total Regents of Cohort', '# Advanced Regents', '% Advanced Regents of Cohort', '# Dropout', '% Dropout']
column_list
# Out:
# ['DBN',
#  'School Name',
#  'Cohort Year',
#  'Cohort',
#  'Category',
#  '# Total Cohort',
#  '# Grads',
#  '% Grads',
#  '# Total Regents',
#  '% Total Regents of Cohort',
#  '# Advanced Regents',
#  '% Advanced Regents of Cohort',
#  '# Dropout',
#  '% Dropout']

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/ethnicity_black.csv"
black_all_df = pd.read_csv(file_path)
black_all_df
# Out:
#          dbn                     school_name  cohort_year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 6982  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 6983  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2004
# 6984  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 6985  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 6986  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       black_num_total_cohort  black_num_grads  black_percent_grads  \
# 0                         17               16                 94.1
# 1                         11               10                 90.9
# ...

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/ethnicity_native_american.csv"
native_american_all_df = pd.read_csv(file_path)
native_american_all_df
# Out:
#          dbn                          school_name  cohort_year  \
# 0     01M292           ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292           ORCHARD COLLEGIATE ACADEMY         2011
# 2     01M292           ORCHARD COLLEGIATE ACADEMY         2010
# 3     01M292           ORCHARD COLLEGIATE ACADEMY         2004
# 4     01M448  UNIVERSITY NEIGHBORHOOD HIGH SCHOOL         2017
# ...      ...                                  ...          ...
# 3024  32K564       BUSHWICK COMMUNITY HIGH SCHOOL         2017
# 3025  32K564       BUSHWICK COMMUNITY HIGH SCHOOL         2012
# 3026  32K564       BUSHWICK COMMUNITY HIGH SCHOOL         2009
# 3027  32K564       BUSHWICK COMMUNITY HIGH SCHOOL         2008
# 3028  32K564       BUSHWICK COMMUNITY HIGH SCHOOL         2007
#
#       native_american_num_total_cohort  native_american_num_grads  \
# 0                                    1                          0
# 1                                    2                          0
# ...

# %%
# Load the dataset SWD
file_path = "/Users/pace/Desktop/Columbia Bootcamp/Final Project/ethnicity_white.csv"
white_all_df = pd.read_csv(file_path)
white_all_df
# Out:
#          dbn                     school_name  cohort_year  \
# 0     01M292      ORCHARD COLLEGIATE ACADEMY         2017
# 1     01M292      ORCHARD COLLEGIATE ACADEMY         2016
# 2     01M292      ORCHARD COLLEGIATE ACADEMY         2015
# 3     01M292      ORCHARD COLLEGIATE ACADEMY         2014
# 4     01M292      ORCHARD COLLEGIATE ACADEMY         2013
# ...      ...                             ...          ...
# 5512  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2006
# 5513  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2005
# 5514  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2003
# 5515  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2002
# 5516  32K564  BUSHWICK COMMUNITY HIGH SCHOOL         2001
#
#       white_num_total_cohort  white_num_grads  white_percent_grads  \
# 0                          1                0                  0.0
# 1                          3                0                  0.0
# ...
